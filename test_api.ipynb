# %%
from api import API
import logging

# Setup logging to console
logging.basicConfig(level=logging.INFO)


print("Testing API...")
api = API()
    
    # Test add_list
api.add_list(["AAPL"])
print("Added AAPL to list.")
    
    # Test get_financials
print("Fetching financials...")
api.get_financials()
data, errors, time = api.get_all()
    
print(f"Fetched {len(data)} dataframes.")
if data:
    print(f"First dataframe shape: {data[0].shape}")
    print(f"First dataframe columns: {data[0].columns}")
    
if errors:
    print(f"Errors: {errors}")
        
# Test get_daily_prices
print("Fetching daily prices...")
prices = api.get_daily_prices()
print(f"Fetched {len(prices)} price dataframes.")
if prices:
    print(f"First price dataframe shape: {prices[0].shape}")

    # Test get_earnings_date
print("Fetching earnings date...")
earnings = api.get_earnings_date()
print("Earnings date dataframe:")
print(earnings)
# Out:
# Testing API...
# Added AAPL to list.
# Fetching financials...
# Fetched 6 dataframes.
# First dataframe shape: (195, 9)
# First dataframe columns: Index(['field_name', 'fiscal_date', 'field_value', 'ticker', 'unit', 'source',
#        'period_type', 'created_at', 'table_name'],
#       dtype='object')
# Fetching daily prices...
# c:\Users\andre\OneDrive\Dokument\vscode\Database_builder\Database_building\api.py:98: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, period="max", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Fetched 1 price dataframes.
# First price dataframe shape: (11333, 6)
# Fetching earnings date...
# Earnings date dataframe:
#   Symbol Earnings date
# 0   AAPL    2026-01-29

# %%
data[0]
# Out:
#                                             field_name fiscal_date  \
# 0                              TaxEffectOfUnusualItems  2025-09-30
# 1                                      TaxRateForCalcs  2025-09-30
# 2                                     NormalizedEBITDA  2025-09-30
# 3    NetIncomeFromContinuingOperationNetMinorityInt...  2025-09-30
# 4                               ReconciledDepreciation  2025-09-30
# ..                                                 ...         ...
# 190                    SellingGeneralAndAdministration  2021-09-30
# 191                                        GrossProfit  2021-09-30
# 192                                      CostOfRevenue  2021-09-30
# 193                                       TotalRevenue  2021-09-30
# 194                                   OperatingRevenue  2021-09-30
#
#       field_value ticker      unit    source period_type  \
# 0    0.000000e+00   AAPL  currency  yfinance      Annual
# ...

# %%
import yfinance as yf
t = yf.Ticker('AAPL')
print('Testing new API methods:')
df = t.get_income_stmt(freq='yearly')
print(f'Annual income: empty={df.empty}, shape={df.shape if not df.empty else None}')
df2 = t.get_income_stmt(freq='quarterly')
print(f'Quarterly income: empty={df2.empty}, shape={df2.shape if not df2.empty else None}')
# Out:
# Testing new API methods:
# Annual income: empty=False, shape=(39, 5)
# Quarterly income: empty=False, shape=(33, 5)

# %%
data[0]
# Out:
#             Tax Effect Of Unusual Items  Tax Rate For Calcs  \
# 2024-09-30                          0.0            0.210000
# 2024-12-31                          0.0            0.147000
# 2025-03-31                          0.0            0.155000
# 2025-06-30                          0.0            0.164000
# 2025-09-30                          0.0            0.162724
#
#             Normalized EBITDA  \
# 2024-09-30       3.250200e+10
# 2024-12-31       4.591200e+10
# 2025-03-31       3.225000e+10
# 2025-06-30       3.103200e+10
# 2025-09-30       3.555400e+10
#
#             Net Income From Continuing Operation Net Minority Interest  \
# 2024-09-30                                       1.473600e+10
# 2024-12-31                                       3.633000e+10
# 2025-03-31                                       2.478000e+10
# 2025-06-30                                       2.343400e+10
# 2025-09-30                                       2.746600e+10
#
# ...

# %%
data[1]
# Out:
#             Ordinary Shares Number  Share Issued      Net Debt    Total Debt  \
# 2024-09-30            1.511679e+10  1.511679e+10  7.668600e+10  1.066290e+11
# 2024-12-31            1.503787e+10  1.503787e+10  6.650000e+10  9.679900e+10
# 2025-03-31            1.493932e+10  1.493932e+10  7.002400e+10  9.818600e+10
# 2025-06-30            1.485672e+10  1.485672e+10  6.542900e+10  1.016980e+11
# 2025-09-30            1.477326e+10  1.477326e+10  6.272300e+10  9.865700e+10
#
#             Tangible Book Value  Invested Capital  Working Capital  \
# 2024-09-30         5.695000e+10      1.635790e+11    -2.340500e+10
# 2024-12-31         6.675800e+10      1.635570e+11    -1.112500e+10
# 2025-03-31         6.679600e+10      1.649820e+11    -2.589700e+10
# 2025-06-30         6.583000e+10      1.675280e+11    -1.862900e+10
# 2025-09-30         7.373300e+10      1.723900e+11    -1.767400e+10
#
#             Net Tangible Assets  Common Stock Equity  Total Capitalization  \
# ...

# %%
data[2]
# Out:
#             Free Cash Flow  Repurchase Of Capital Stock  Repayment Of Debt  \
# 2024-03-31             NaN                          NaN                NaN
# 2024-06-30             NaN                          NaN                NaN
# 2024-09-30    2.390300e+10                -2.508300e+10       4.270000e+08
# 2024-12-31    2.699500e+10                -2.360600e+10      -8.953000e+09
# 2025-03-31    2.088100e+10                -2.589800e+10       9.760000e+08
# 2025-06-30    2.440500e+10                -2.107500e+10      -1.770000e+09
# 2025-09-30    2.648600e+10                -2.013200e+10      -1.185000e+09
#
#             Issuance Of Debt  Capital Expenditure  \
# 2024-03-31               NaN                  NaN
# 2024-06-30               NaN                  NaN
# 2024-09-30               0.0        -2.908000e+09
# 2024-12-31               NaN        -2.940000e+09
# 2025-03-31               NaN        -3.071000e+09
# 2025-06-30               NaN        -3.462000e+09
# ...

# %%
import pandas as pd 

data_pd = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 import pandas as pd
# ----> 3 data_pd = pd.DataFrame(data)
#
# File c:\Users\andre\OneDrive\Dokument\vscode\Database_builder\Database_building\.venv\Lib\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)    864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
# ...

# %%
import yfinance as yf

# %%
ticker = yf.Ticker("AAPL")

# %%
aapl_cash_flow_yr=ticker.get_cash_flow(freq="yearly")

# %%
aapl_cash_flow_qt=ticker.get_cash_flow(freq="quarterly")

# %%
aapl_cash_flow_yr.loc["FreeCashFlow"]
# Out:
# 2025-09-30    9.876700e+10
# 2024-09-30    1.088070e+11
# 2023-09-30    9.958400e+10
# 2022-09-30    1.114430e+11
# 2021-09-30             NaN
# Name: FreeCashFlow, dtype: float64

# %%
test = ticker.get_income_stmt(freq="yearly")

# %%
test
# Out:
#                                                       2025-09-30  \
# TaxEffectOfUnusualItems                             0.000000e+00
# TaxRateForCalcs                                     1.560000e-01
# NormalizedEBITDA                                    1.447480e+11
# NetIncomeFromContinuingOperationNetMinorityInte...  1.120100e+11
# ReconciledDepreciation                              1.169800e+10
# ReconciledCostOfRevenue                             2.209600e+11
# EBITDA                                              1.447480e+11
# EBIT                                                1.330500e+11
# NetInterestIncome                                            NaN
# InterestExpense                                              NaN
# InterestIncome                                               NaN
# NormalizedIncome                                    1.120100e+11
# NetIncomeFromContinuingAndDiscontinuedOperation     1.120100e+11
# ...

# %%
aapl_cash_flow_qt.loc["FreeCashFlow"].sum()
# Out:
# np.float64(122670000000.0)

# %%
import pandas as pd
test = ticker.cash_flow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 import pandas as pd
# ----> 2 test = ticker.cash_flow()
#
# TypeError: 'DataFrame' object is not callable

# %%
ticker.get_balance_sheet(freq="quarterly")
# Out:
#                                               2025-09-30    2025-06-30  \
# OrdinarySharesNumber                        1.477326e+10  1.485672e+10
# ShareIssued                                 1.477326e+10  1.485672e+10
# NetDebt                                     6.272300e+10  6.542900e+10
# TotalDebt                                   9.865700e+10  1.016980e+11
# TangibleBookValue                           7.373300e+10  6.583000e+10
# ...                                                  ...           ...
# CashCashEquivalentsAndShortTermInvestments  5.469700e+10  5.537200e+10
# OtherShortTermInvestments                   1.876300e+10  1.910300e+10
# CashAndCashEquivalents                      3.593400e+10  3.626900e+10
# CashEquivalents                             7.667000e+09  9.583000e+09
# CashFinancial                               2.826700e+10  2.668600e+10
#
#                                               2025-03-31    2024-12-31  \
# ...

# %%
ticker.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0
# ...                              ...           ...
# 2024-11-08 00:00:00-05:00   0.250000           0.0
# 2025-02-10 00:00:00-05:00   0.250000           0.0
# 2025-05-12 00:00:00-04:00   0.260000           0.0
# 2025-08-11 00:00:00-04:00   0.260000           0.0
# 2025-11-10 00:00:00-05:00   0.260000           0.0
#
# [94 rows x 2 columns]

# %%
import yfinance as yf

try:
    print("Downloading AAPL...")
    data = yf.download("AAPL", period="max", interval="1d")
    print(data.head())
    print(data.info())
    print(data["Date"].min())
    print(data["Date"].max())
    print("Fetching Ticker...")
    ticker = yf.Ticker("AAPL")
    print(ticker.info.get('symbol'))
except Exception as e:
    print(e)
# Out:
# ...
# C:\Users\andre\AppData\Local\Temp\ipykernel_37492\2930119172.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", period="max", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 1980-12-12  0.098390  0.098817  0.098390  0.098390  469033600
# 1980-12-15  0.093256  0.093684  0.093256  0.093684  175884800
# 1980-12-16  0.086412  0.086839  0.086412  0.086839  105728000
# 1980-12-17  0.088550  0.088978  0.088550  0.088550   86441600
# 1980-12-18  0.091118  0.091545  0.091118  0.091118   73449600
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11333 entries, 1980-12-12 to 2025-11-28
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
# ...

# %%
data.head()
# Out:
# Price          Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 1980-12-12  0.098390  0.098817  0.098390  0.098390  469033600
# 1980-12-15  0.093256  0.093684  0.093256  0.093684  175884800
# 1980-12-16  0.086412  0.086839  0.086412  0.086839  105728000
# 1980-12-17  0.088550  0.088978  0.088550  0.088550   86441600
# 1980-12-18  0.091118  0.091545  0.091118  0.091118   73449600

# %%
data.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-11-21  271.489990  273.329987  265.670013  265.950012  59030800
# 2025-11-24  275.920013  277.000000  270.899994  270.899994  65585800
# 2025-11-25  276.970001  280.380005  275.250000  275.269989  46914200
# 2025-11-26  277.549988  279.529999  276.630005  276.959991  33431400
# 2025-11-28  278.850006  279.000000  275.989990  277.260010  20135600

# %%
import sp500_list_getter

sp500 = sp500_list_getter.GetSp500List()
sp500.request_to_pd()
sp500.get_earnings_date()
sp500_df = sp500.get_df()
sp500_df.to_csv('data.csv', sep=',', index=False)
print(sp500_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 4
#       1 import sp500_list_getter
#       3 sp500 = sp500_list_getter.GetSp500List()
# ----> 4 sp500.request_to_pd()
#       5 sp500.get_earnings_date()
#       6 sp500_df = sp500.get_df()
#
# File c:\Users\andre\OneDrive\Dokument\vscode\Database_builder\Database_building\sp500_list_getter.py:29, in GetSp500List.request_to_pd(self)
#      27 def request_to_pd(self):
#      28     self.data = requests.get(self.url).json()
# ---> 29     df = pd.DataFrame(columns = self.data[0][0])
#      30     for i in range(len(self.data[0])-1):
#      31         df.loc[len(df)] = self.data[0][i+1]
#
# KeyError: 0

# %%
import pandas as pd
import requests
import logging

# Vi behöver inte numpy längre för att lägga till nan-kolumner.
# Vi tar bort yfinance-importen eftersom vi inte ska hämta finansiell data.

logger = logging.getLogger()
logging.basicConfig(
    filename="logfile.log",
    format="[%(asctime)s][%(levelname)s] %(message)s",
    level=logging.DEBUG,
    datefmt="%Y-%m-%d %H:%M"
    )

"""
Denna fil används för att skrapa S&P 500-listan direkt från slickcharts.com 
och fylla en DataFrame med bolagsnamn och symboler. Den är inte avsedd för
schemalagd körning.
"""


class GetSp500List:
    def __init__(self) -> None:
        # Uppdaterad URL till Slickcharts S&P 500-sida
        self.url = "https://www.slickcharts.com/sp500"
        self.df = pd.DataFrame()
        
    def request_to_pd(self):
        """
        Hämtar HTML-tabellen från Slickcharts URL och konverterar den till en Pandas DataFrame.
        Använder 'requests' för att hämta innehållet och 'pandas.read_html' för att parsa tabellen.
        """
        try:
            logger.info(f"Försöker hämta data från {self.url}...")
            
            # Använd pandas.read_html för att automatiskt hitta och parsa tabeller.
            # Vi använder 'attrs' för att specificera den unika CSS-klassen på den önskade tabellen.
            df_list = pd.read_html(
                self.url,
                attrs={'class': 'table table-hover table-borderless table-sm'}
            )

            if not df_list:
                logger.error("Kunde inte hitta S&P 500-tabellen med den angivna CSS-klassen.")
                return

            # Den önskade tabellen är den första (och troligen enda) som matchar
            df = df_list[0]
            
            # Kolumnerna från Slickcharts är: '#', 'Company', 'Symbol', 'Weight', 'Price', 'Chg', '% Chg'
            # Vi väljer endast 'Company' och 'Symbol'.
            self.df = df[["#", "Company", "Symbol", "Weight"]].copy()
            self.df.set_index("#", inplace=True)            
            # Då symbolen 'BRK.B' på Slickcharts blir till 'BRK.B' i DataFramen, 
            # och inte krånglar som i yfinance, kan vi behålla den som den är. 
            # Om du vill byta ut . mot - för att vara konsekvent i databasen:
            # self.df["Symbol"] = self.df["Symbol"].str.replace(".","-")

            # Säkerställer att kolumnerna har tydliga namn
            self.df = self.df.rename(columns={'Company': 'CompanyName', 'Symbol': 'Symbol'})
            
            logger.info(f"Hämtade framgångsrikt {len(self.df)} bolagssymboler.")

        except requests.exceptions.RequestException as e:
            logger.error(f"Kunde inte ansluta till Slickcharts ({self.url}). Kontrollera din anslutning: {e}")
        except Exception as e:
            logger.error(f"Ett oväntat fel inträffade under HTML-skrapning: {e}")
    
    # Den gamla metoden get_earnings_date/get_company_info är borttagen som önskat.
            
    def get_df(self):
        """Returnerar den skrapade DataFramen."""
        return self.df

# Exempel på körning för att testa skriptet:
if __name__ == "__main__":
    sp500_scraper = GetSp500List()
    
    # 1. Hämta S&P 500-listan genom HTML-skrapning
    sp500_scraper.request_to_pd()
    
    # 2. Skriv ut resultatet (de första 10 raderna)
    final_df = sp500_scraper.get_df()
    
    if not final_df.empty:
        print("\n--- SLUTRESULTAT (FÖRSTA 10 RADER) ---")
        print(final_df.head(10))
    else:
        print("\n--- Kunde inte hämta data. Kontrollera loggfilen (logfile.log) för fel. ---")
# Out:
# --- SLUTRESULTAT (FÖRSTA 10 RADER) ---
#                 CompanyName Symbol Weight
# #
# 1                    Nvidia   NVDA  6.97%
# 2                Apple Inc.   AAPL  6.67%
# 3                 Microsoft   MSFT  5.92%
# 4                    Amazon   AMZN  4.04%
# 5   Alphabet Inc. (Class A)  GOOGL  3.24%
# 6                  Broadcom   AVGO  3.08%
# 7   Alphabet Inc. (Class C)   GOOG  3.01%
# 8            Meta Platforms   META  2.64%
# 9               Tesla, Inc.   TSLA  2.32%
# 10       Berkshire Hathaway  BRK.B  1.79%

# %%
final_df.set_index("#", inplace=True)

# %%
final_df
# Out:
#                           CompanyName Symbol Weight
# #
# 1                              Nvidia   NVDA  6.97%
# 2                          Apple Inc.   AAPL  6.67%
# 3                           Microsoft   MSFT  5.92%
# 4                              Amazon   AMZN  4.04%
# 5             Alphabet Inc. (Class A)  GOOGL  3.24%
# ..                                ...    ...    ...
# 499                 Molina Healthcare    MOH  0.01%
# 500                   LKQ Corporation    LKQ  0.01%
# 501  Solstice Advanced Materials Inc.   SOLS  0.01%
# 502                 Mohawk Industries    MHK  0.01%
# 503               News Corp (Class B)    NWS  0.01%
#
# [503 rows x 3 columns]

# %%
# !pip install dotenv
# Out:
# ...
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# ...
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import finnhub
from dotenv import load_dotenv  
import os
load_dotenv()

# Setup client
finnhub_client = finnhub.Client(api_key=os.environ.get("finnhubb_key"))

# %%
res = finnhub_client.financials_reported(symbol='AAPL', freq='annual', startDate='2000-01-01', endDate='2025-10-31')
print(res)
# Out:
# {'cik': '320193', 'data': [{'accessNumber': '0000320193-25-000079', 'symbol': 'AAPL', 'cik': '320193', 'year': 2025, 'quarter': 0, 'form': '10-K', 'startDate': '2024-09-29 00:00:00', 'endDate': '2025-09-27 00:00:00', 'filedDate': '2025-10-31 00:00:00', 'acceptedDate': '2025-10-31 06:01:26', 'report': {'bs': [{'concept': 'us-gaap_CashAndCashEquivalentsAtCarryingValue', 'unit': 'usd', 'label': 'Cash and cash equivalents', 'value': 35934000000.0}, {'concept': 'us-gaap_MarketableSecuritiesCurrent', 'unit': 'usd', 'label': 'Marketable securities', 'value': 18763000000.0}, {'concept': 'us-gaap_AccountsReceivableNetCurrent', 'unit': 'usd', 'label': 'Accounts receivable, net', 'value': 39777000000}, {'concept': 'us-gaap_NontradeReceivablesCurrent', 'unit': 'usd', 'label': 'Vendor non-trade receivables', 'value': 33180000000}, {'concept': 'us-gaap_InventoryNet', 'unit': 'usd', 'label': 'Inventories', 'value': 5718000000}, {'concept': 'us-gaap_OtherAssetsCurrent', 'unit': 'usd', 'label': 'Othe
# ...
